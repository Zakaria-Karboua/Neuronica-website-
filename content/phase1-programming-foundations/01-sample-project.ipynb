# %% [markdown]
# # Phase 1 Project — Command Line To-Do App
# A small project applying data structures + file I/O from Phase 1.

# %%
tasks = []
def add_task(t):
    tasks.append({'title': t, 'done': False})
add_task('Learn Python fundamentals')
print(tasks)
